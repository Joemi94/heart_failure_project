# %%
import pandas as pd 
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
path = r'C:\Users\User\Documents\IMPORTANT FILES\TECHTERN\Work Files\heart2.csv' 
df = pd.read_csv(path)
df
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# 1      0      2       1
# 2      0      2       1
# 3      0      2       1
# 4      0      2       1
# ..   ...    ...     ...
# 298    0      3       0
# 299    0      3       0
# 300    2      3       0
# 301    1      3       0
# 302    1      2       0
#
# [303 rows x 14 columns]

# %% [markdown]
# # EXPLORATION DATA ANALYSIS - EDA

# %%
#inspecting the shape of the Data frame
df.shape
# Out:
# (303, 14)

# %%
#Inspecting the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trtbps    303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalachh  303 non-null    int64
#  8   exng      303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slp       303 non-null    int64
#  11  caa       303 non-null    int64
#  12  thall     303 non-null    int64
#  13  output    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
cols = df.columns
for col in cols:
    print(f'Unique value in {col} = {df[col].unique()}')   
    print(f'Number of unique value in {col} = {df[col].nunique()} \n')
# Out:
# Unique value in age = [63 37 41 56 57 44 52 54 48 49 64 58 50 66 43 69 59 42 61 40 71 51 65 53
#  46 45 39 47 62 34 35 29 55 60 67 68 74 76 70 38 77]
# Number of unique value in age = 41
#
# Unique value in sex = [1 0]
# Number of unique value in sex = 2
#
# Unique value in cp = [3 2 1 0]
# Number of unique value in cp = 4
#
# Unique value in trtbps = [145 130 120 140 172 150 110 135 160 105 125 142 155 104 138 128 108 134
#  122 115 118 100 124  94 112 102 152 101 132 148 178 129 180 136 126 106
#  156 170 146 117 200 165 174 192 144 123 154 114 164]
# Number of unique value in trtbps = 49
#
# Unique value in chol = [233 250 204 236 354 192 294 263 199 168 239 275 266 211 283 219 340 226
#  247 234 243 302 212 175 417 197 198 177 273 213 304 232 269 360 308 245
#  208 264 321 325 235 257 216 256 231 141 252 201 222 260 182 303 265 309
#  186 203 183 220 209 258 227 261 221 205 240 318 298 564 277 214 248 255
#  207 223 288 160 394 315 246 244 270 195 196 254 126 313 262 215 193 271
#  268 267 210 295 306 178 242 180 228 149 278 253 342 157 286 229 284 224
#  206 167 230 335 276 353 225 330 290 172 305 188 282 185 326 274 164 307
#  249 341 407 217 174 281 289 322 299 300 293 184 409 259 200 327 237 218
#  319 166 311 169 187 176 241 131]
# Number of unique value in chol = 152
#
# Unique value in fbs = [1 0]
# Number of unique value in fbs = 2
#
# Unique value in restecg = [0 1 2]
# Number of unique value in restecg = 3
#
# Unique value in thalachh = [150 187 172 178 163 148 153 173 162 174 160 139 171 144 158 114 151 161
#  179 137 157 123 152 168 140 188 125 170 165 142 180 143 182 156 115 149
#  146 175 186 185 159 130 190 132 147 154 202 166 164 184 122 169 138 111
#  145 194 131 133 155 167 192 121  96 126 105 181 116 108 129 120 112 128
#  109 113  99 177 141 136  97 127 103 124  88 195 106  95 117  71 118 134
#   90]
# Number of unique value in thalachh = 91
#
# Unique value in exng = [0 1]
# Number of unique value in exng = 2
#
# Unique value in oldpeak = [2.3 3.5 1.4 0.8 0.6 0.4 1.3 0.  0.5 1.6 1.2 0.2 1.8 1.  2.6 1.5 3.  2.4
#  0.1 1.9 4.2 1.1 2.  0.7 0.3 0.9 3.6 3.1 3.2 2.5 2.2 2.8 3.4 6.2 4.  5.6
#  2.9 2.1 3.8 4.4]
# Number of unique value in oldpeak = 40
#
# Unique value in slp = [0 2 1]
# Number of unique value in slp = 3
#
# Unique value in caa = [0 2 1 3 4]
# Number of unique value in caa = 5
#
# Unique value in thall = [1 2 3 0]
# Number of unique value in thall = 4
#
# Unique value in output = [1 0]
# Number of unique value in output = 2

# %%
#Checking for Missing Value
df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trtbps      0
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exng        0
# oldpeak     0
# slp         0
# caa         0
# thall       0
# output      0
# dtype: int64

# %%
#Checking for duplicates
df.duplicated().sum()
# Out:
# 1

# %%
#Inspecting for Outliers
df.plot(kind  = 'box', subplots = True, sharex = False, layout = (4,4), figsize = (20,15))
# Out:
# age            AxesSubplot(0.125,0.712609;0.168478x0.167391)
# sex         AxesSubplot(0.327174,0.712609;0.168478x0.167391)
# cp          AxesSubplot(0.529348,0.712609;0.168478x0.167391)
# trtbps      AxesSubplot(0.731522,0.712609;0.168478x0.167391)
# chol           AxesSubplot(0.125,0.511739;0.168478x0.167391)
# fbs         AxesSubplot(0.327174,0.511739;0.168478x0.167391)
# restecg     AxesSubplot(0.529348,0.511739;0.168478x0.167391)
# thalachh    AxesSubplot(0.731522,0.511739;0.168478x0.167391)
# exng            AxesSubplot(0.125,0.31087;0.168478x0.167391)
# oldpeak      AxesSubplot(0.327174,0.31087;0.168478x0.167391)
# slp          AxesSubplot(0.529348,0.31087;0.168478x0.167391)
# caa          AxesSubplot(0.731522,0.31087;0.168478x0.167391)
# thall              AxesSubplot(0.125,0.11;0.168478x0.167391)
# output          AxesSubplot(0.327174,0.11;0.168478x0.167391)
# dtype: object

# %%
#Checking for imbalance in the target value
print(df['output'].value_counts()) 
sns.countplot(x = 'output', data=df)
# Out:
# 1    165
# 0    138
# Name: output, dtype: int64
# <AxesSubplot:xlabel='output', ylabel='count'>

# %% [markdown]
# Inference
# 1. Dataset contains 14 features and 303 records
# 2. Dataset contains only numeric values
# 3. Contains 1 duplicates values
# 4. Contains no missing values
# 5. Some features in the Dataset contains outliers
# 6. No imbalance in the target variable

# %% [markdown]
# # DATA CLEANING

# %%
#Dropping Duplicates
dfCopy = df.drop_duplicates(inplace = False)

# %%
dfCopy.describe().T
# Out:
#           count        mean        std    min     25%    50%     75%    max
# age       302.0   54.420530   9.047970   29.0   48.00   55.5   61.00   77.0
# sex       302.0    0.682119   0.466426    0.0    0.00    1.0    1.00    1.0
# cp        302.0    0.963576   1.032044    0.0    0.00    1.0    2.00    3.0
# trtbps    302.0  131.602649  17.563394   94.0  120.00  130.0  140.00  200.0
# chol      302.0  246.500000  51.753489  126.0  211.00  240.5  274.75  564.0
# fbs       302.0    0.149007   0.356686    0.0    0.00    0.0    0.00    1.0
# restecg   302.0    0.526490   0.526027    0.0    0.00    1.0    1.00    2.0
# thalachh  302.0  149.569536  22.903527   71.0  133.25  152.5  166.00  202.0
# exng      302.0    0.327815   0.470196    0.0    0.00    0.0    1.00    1.0
# oldpeak   302.0    1.043046   1.161452    0.0    0.00    0.8    1.60    6.2
# slp       302.0    1.397351   0.616274    0.0    1.00    1.0    2.00    2.0
# caa       302.0    0.718543   1.006748    0.0    0.00    0.0    1.00    4.0
# thall     302.0    2.314570   0.613026    0.0    2.00    2.0    3.00    3.0
# output    302.0    0.543046   0.498970    0.0    0.00    1.0    1.00    1.0
